# %% [markdown]
# # Machine Learning Foundation - Assignment

# %% [markdown]
# ## Problem Statement
#
# __" Infant Mortality Rate (IMR) "__
# _Infant mortality is the death of an infant before his or her first birthday._
#
# The problem statement is to predict which factors are contributing to decrease Infant Mortality Rate.
#
# {Infant mortality rate (IMR) is the number of deaths per 1,000 live births of children under one year of age. The rate for a given region is the number of children dying under one year of age, divided by the number of live births during the year, multiplied by 1,000}.
#
# There are a number of causes of infant mortality, including poor sanitation, poor water quality, malnourishment of the mother and infant, inadequate prenatal and medical care, and use of infant formula as a breast milk substitute. Contributing to the problem are poor education and limited access to birth control, both of which lead to high numbers of births per mother and short intervals between births. High-frequency births allow less recovery time for mothers and entail potential food shortages in poor families. When women are educated, they are more likely to give birth at later ages and to seek better health care and better education for their children, including their daughters.
#
#
# - We want to find a function that given input Independent Variables to __predicts the IMR__.
#
# - Which Independent Variables are __contributes__ to reduce IMR ?
#
# - Visualize the __relationship__ between the _features_ and the _response_ using scatter plots.

# %% [markdown]
# ## About NFHS :
#
# __National Family Health Survey ( NFHS - I, II, III & IV ) data considered for developing a predictive model through using Regression Analysis.__
#
# The National Family Health Survey (NFHS) is a large-scale, multi-round survey conducted in a representative sample of households throughout India. The Ministry of Health and Family Welfare (MOHFW), Government of India, conducts the survey.
#
# - The First National Family Health Survey (NFHS-1) was conducted in 1992-1993.
# - The Second National Family Health Survey (NFHS-2) was conducted in 1998-1999.
# - The Third National Family Health Survey (NFHS-3) was carried out in 2005-2006.
# - The Fourth National Family Health Survey (NFHS-4) was carried out in 2015-2016.
#
# Conducted in all States of India with added features on the quality of health and family planning services, domestic violence, reproductive health, anemia, the nutrition of women, and the status of women.

# %% [markdown]
# ## Data Loading and Description
#
# __For the Project purpose i have considered the following featurs :__
#
# __Independent Variables :-__
#
# - Households with electricity (%)
# - Households with an improved drinking-water source (%)
# - Households using improved sanitation facility (%)
# - Women who are literate (%)
# - Women age 20-24 years married before age 18 years (%)
# - Total fertility rate (children per woman)
# - Mothers who had antenatal check-up in the first trimester (%)
# - Mothers who had at least 4 antenatal care visits (%)
# - Mothers who had full antenatal care (%)
# - Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)
# - Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)
# - Institutional births (%)
# - Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)
# - Children who received a health check after birth from a doctor/nurse/LHV/ANM/ midwife/other health personnel within 2 days of birth (%)
# - Children under age 6 months exclusively breastfed (%)
#
# __Dependent Variables :-__
#
# - Infant mortality rate (IMR)   {Deaths per 1,000 live births of children under one year of age}

# %% [markdown]
# ## Importing Packages

# %%
import numpy as np                     # Implemennts milti-dimensional array and matrices
import pandas as pd                    # For data manipulation and analysis
from sklearn import metrics            # A library contains efficient tools for machine learning and statistical modeling including classification, regression, clustering and dimensionality reduction.
import matplotlib.pyplot as plt        # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns                  # Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
sns.set()

from subprocess import check_output

# %% [markdown]
# ## Importing the Dataset

# %%
# Reading CSV file

df = pd.read_csv("NFHS (1-4).csv")     # Importing training dataset using pd.read_csv " National Family Health Survey - 1, 2, 3 & 4 "
df.head()
# Out:
#   India/States/UTs  Survey   Area  \
# 0            India  NFHS-4  Total
# 1            India  NFHS-4  Rural
# 2            India  NFHS-4  Urban
# 3            India  NFHS-3  Total
# 4   Andhra Pradesh  NFHS-4  Total
#
#    Population and Household Profile - Households with electricity (%)  \
# 0                                               88.2
# 1                                               83.2
# 2                                               97.5
# 3                                               67.9
# 4                                               98.8
#
#    Population and Household Profile - Households with an improved drinking-water source (%)  \
# 0                                               89.9
# 1                                               89.3
# 2                                               91.1
# 3                                               87.6
# 4                                               72.7
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape            # To know the number of Raws & Columns in the data set
# Out:
# (200, 18)

# %%
df.info()

#float64 = continous variable
#object = categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 18 columns):
# India/States/UTs                                                                                                                                                                                              200 non-null object
# Survey                                                                                                                                                                                                        200 non-null object
# Area                                                                                                                                                                                                          192 non-null object
# ...

# %%
df.describe()     # To know the summary statistics
# Out:
#        Population and Household Profile - Households with electricity (%)  \
# count                                         166.000000
# mean                                           87.090361
# std                                            17.759399
# min                                            18.200000
# 25%                                            83.275000
# 50%                                            95.050000
# 75%                                            99.000000
# max                                           100.000000
#
#        Population and Household Profile - Households with an improved drinking-water source (%)  \
# count                                         192.000000
# mean                                           81.614062
# std                                            16.118074
# min                                            19.900000
# 25%                                            74.675000
# ...

# %% [markdown]
# There are 200 **Observations** and 18 Variables, and missing data is exists in the dataset. Mean is slightly right skewed due to outlier existence, where significant difference between Min & Max.

# %% [markdown]
# ##  Preprocessing the data & EDA

# %% [markdown]
#    - Dealing with missing values<br/>
#    - Dropping/Replacing missing entries .
#    - Replacing missing values with mean values.
#    - Dropping the column as it has too many _null_ values.
#    - Renaming column headings where too long headings

# %%
dfIN = df[df['Area'] == 'Total'][df['India/States/UTs'] == 'India']     # Select raws whtere Area = Total & State = India to show National level IMR.

dfIN.groupby('Survey',).mean()['Infant and Child Mortality Rates (per 1000 live births) - Infant mortality rate (IMR)'].plot.bar(figsize=(10,5), colormap='tab10', fontsize=13, yticks=np.arange(0, 101, 10))
plt.xlabel('NFHS')
plt.ylabel('Infant mortality rate (IMR)')
plt.title('National Family Health Survey - IMR Trend',fontsize=18)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# Text(0.5, 1.0, 'National Family Health Survey - IMR Trend')

# %%
df4 = df[df['Survey'] == 'NFHS-4'][df['Area'] == 'Total'][df['India/States/UTs'] != 'India']    # Select raws whtere Area = Total & State = India to show National level IMR.

df4.groupby('India/States/UTs',).mean()['Infant and Child Mortality Rates (per 1000 live births) - Infant mortality rate (IMR)'].sort_values(ascending=False).plot.bar(figsize=(20,6), colormap='tab10', fontsize=13, yticks=np.arange(0, 101, 10))
plt.xlabel('NFHS')
plt.ylabel('Infant mortality rate (IMR)')
plt.title('State wise National Family Health Survey - 4  vs  IMR Trend',fontsize=18)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# Text(0.5, 1.0, 'State wise National Family Health Survey - 4  vs  IMR Trend')

# %%
# Select raws whtere Area = Total & State = India to show National level IMR.

df99 = df[df['Area'] == 'Total'][df['India/States/UTs'] != 'India']    
#df2=df1[df1['Survey'] == 'NFHS-4']
df99.count()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# India/States/UTs                                                                                                                                                                                              115
# Survey                                                                                                                                                                                                        115
# Area                                                                                                                                                                                                          115
# ...

# %%
# Drop columns - Survey, Area, State Names

df11 = df99.drop(['Survey'], axis = 1)                                  
df12 = df11.drop(['Area'], axis = 1)
df13 = df12.drop(['India/States/UTs'], axis = 1)
df14 = df13.drop(['Population and Household Profile - Households with electricity (%)'], axis = 1)
df15 = df14.drop(['Maternity Care (for last birth in the 5 years before the survey) - Mothers who had at least 4 antenatal care visits (%)'], axis = 1)
df16 = df15.drop(['Maternity Care (for last birth in the 5 years before the survey) - Mothers who had full antenatal care (%)'], axis = 1)
df17 = df16.drop(['Maternity Care (for last birth in the 5 years before the survey) - Mothers who consumed iron folic acid for 100 days or more when they were pregnant (%)'], axis = 1)
df18 = df17.drop(['Maternity Care (for last birth in the 5 years before the survey) - Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (%)'], axis = 1)
df3 = df18.drop(['Maternity Care (for last birth in the 5 years before the survey) - Children who received a health check after birth from a doctor/nurse/LHV/ANM/ midwife/other health personnel within 2 days of birth (%)'], axis = 1)

df3.count()
# Out:
# Population and Household Profile - Households with an improved drinking-water source (%)                                            115
# Population and Household Profile - Households using improved sanitation facility (%)                                                115
# Characteristics of Adults (age 15-49) - Women who are literate (%)                                                                  115
# Marriage and Fertility - Women age 20-24 years married before age 18 years (%)                                                      115
# Marriage and Fertility - Total fertility rate (children per woman)                                                                  115
# Maternity Care (for last birth in the 5 years before the survey) - Mothers who had antenatal check-up in the first trimester (%)    115
# Delivery Care (for births in the 5 years before the survey) - Institutional births (%)                                              115
# ...

# %%
df3.rename(columns = {'Population and Household Profile - Households with an improved drinking-water source (%)' : 'DrinkingWater'},inplace = True)
df3.rename(columns = {'Population and Household Profile - Households using improved sanitation facility (%)' : 'Sanitation'},inplace = True)
df3.rename(columns = {'Characteristics of Adults (age 15-49) - Women who are literate (%)' : 'Literate'},inplace = True)
df3.rename(columns = {'Marriage and Fertility - Women age 20-24 years married before age 18 years (%)' : 'MarrageBelow18Yrs'},inplace = True)
df3.rename(columns = {'Marriage and Fertility - Total fertility rate (children per woman)' : 'TFR'},inplace = True)
df3.rename(columns = {'Maternity Care (for last birth in the 5 years before the survey) - Mothers who had antenatal check-up in the first trimester (%)' : 'ANCCheckup'},inplace = True)
df3.rename(columns = {'Delivery Care (for births in the 5 years before the survey) - Institutional births (%)' : 'InstutitionalBirth'},inplace = True)
df3.rename(columns = {'Child Feeding Practices and Nutritional Status of Children - Children under age 6 months exclusively breastfed (%)' : 'Breastfeeding'},inplace = True)
df3.rename(columns = {'Infant and Child Mortality Rates (per 1000 live births) - Infant mortality rate (IMR)' : 'IMR'},inplace = True)
df3.head()
# Out:
#     DrinkingWater  Sanitation  Literate  MarrageBelow18Yrs  TFR  ANCCheckup  \
# 4            72.7        53.6      62.9               32.7  1.8        82.4
# 7            72.7        53.6      62.9               33.0  1.8        82.3
# 8            83.8        47.7      71.8               32.6  2.2        55.1
# 11           72.5        30.7      63.0               38.0  2.4        40.0
# 12           98.2        25.2      49.6               39.1  3.4        34.6
#
#     InstutitionalBirth  Breastfeeding   IMR
# 4                 91.6           70.2  35.0
# 7                 91.5           70.2  35.0
# 8                 70.6           63.5  48.0
# 11                22.4           63.1  66.0
# 12                63.8           53.5  48.0

# %%
df3.fillna(df3.mean(), inplace=True) #Fill NaN with Mean Value
df3.head()
# Out:
#     DrinkingWater  Sanitation  Literate  MarrageBelow18Yrs  TFR  ANCCheckup  \
# 4            72.7        53.6      62.9               32.7  1.8        82.4
# 7            72.7        53.6      62.9               33.0  1.8        82.3
# 8            83.8        47.7      71.8               32.6  2.2        55.1
# 11           72.5        30.7      63.0               38.0  2.4        40.0
# 12           98.2        25.2      49.6               39.1  3.4        34.6
#
#     InstutitionalBirth  Breastfeeding   IMR
# 4                 91.6           70.2  35.0
# 7                 91.5           70.2  35.0
# 8                 70.6           63.5  48.0
# 11                22.4           63.1  66.0
# 12                63.8           53.5  48.0

# %%
sns.distplot(df3.IMR, color="b")     # Distribution Plot to understand the normal distribution of data for Infant Mortality Rate
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
### removed_outliers 

dfD = pd.DataFrame(np.random.randn(100, 3))
from scipy import stats
df4=df3[(np.abs(stats.zscore(df3)) < 3).all(axis=1)]

df4.count()
# Out:
# DrinkingWater         111
# Sanitation            111
# Literate              111
# MarrageBelow18Yrs     111
# TFR                   111
# ANCCheckup            111
# InstutitionalBirth    111
# Breastfeeding         111
# IMR                   111
# dtype: int64

# %%
sns.distplot(df4.IMR, color="b")     # Distribution Plot to understand the normal distribution of data for Infant Mortality Rate

# %%
# Using seaborn's regplot function to plot the scatter plot for the IMR and other columns with the regression line.

plt.figure(figsize=(6,5))
sns.regplot(data=df4, x='Pronta PTK', y='Pronta EC', color="b")

# %%
df4.corr()
# Out:
#                     DrinkingWater  Sanitation  Literate  MarrageBelow18Yrs  \
# DrinkingWater            1.000000    0.073466  0.231973          -0.137756
# Sanitation               0.073466    1.000000  0.745683          -0.636995
# Literate                 0.231973    0.745683  1.000000          -0.823864
# MarrageBelow18Yrs       -0.137756   -0.636995 -0.823864           1.000000
# TFR                     -0.479291   -0.390648 -0.626270           0.540201
# ANCCheckup               0.011297    0.328218  0.351491          -0.384576
# InstutitionalBirth       0.459196    0.415276  0.668681          -0.549523
# Breastfeeding           -0.018981   -0.003139 -0.044727           0.154851
# IMR                     -0.278666   -0.574515 -0.791720           0.730780
#
#                          TFR  ANCCheckup  InstutitionalBirth  Breastfeeding  \
# DrinkingWater      -0.479291    0.011297            0.459196      -0.018981
# ...

# %%
corr = df4.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr,vmax=.8,linewidth=.01, square = True, annot = True,cmap='YlGnBu',linecolor ='black')
plt.title('Correlation between features')

# |r| < 0.8 - ok range
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %% [markdown]
# __Observation__
#
# - The diagonal of the above matirx shows the auto-correlation of the variables. It is always 1. It can be observed that the correlation between __IMR and Literate (Mother's Education) is highest i.e. -0.79__ __|__ then between __IMR and Mothers Marraged Below 18 Yrs i.e. 0.73__ and then between __IMR and Instutitional Birth i.e. -0.70__.
#
# - correlations can vary from -1 to +1. Closer to +1 means strong positive correlation and close -1 means strong negative correlation. Closer to 0 means not very strongly correlated. variables with __strong correlations__ are mostly probably candidates for __model builing__.

# %% [markdown]
# ## Linear Regression :
#
# __Though the data is contineous in natur, so using the Linear Regression__

# %% [markdown]
# ###  Preparing X and y using pandas

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df4)
dfslr = scaler.transform(df4)

# %%
NFHS = pd.DataFrame(dfslr)
NFHS.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.379248  0.187651 -0.084551  0.086093 -1.082080  0.938069  1.381515
# 1 -0.379248  0.187651 -0.084551  0.102675 -1.082080  0.932931  1.378003
# 2  0.326387 -0.066943  0.473789  0.080566 -0.507799 -0.464729  0.644028
# 3 -0.391962 -0.800520 -0.078277  0.379030 -0.220659 -1.240636 -1.048681
# 4  1.241805 -1.037853 -0.918924  0.439828  1.215045 -1.518113  0.405223
#
#           7         8
# 0  1.276926 -0.617242
# 1  1.276926 -0.617242
# 2  0.879360  0.040990
# 3  0.855625  0.952387
# 4  0.285979  0.040990

# %%
NFHS.columns = ['DrinkingWater','Sanitation','Literate','MarrageBelow18Yrs','TFR','ANCCheckup','InstutitionalBirth','Breastfeeding','IMR']
NFHS.head()
# Out:
#    DrinkingWater  Sanitation  Literate  MarrageBelow18Yrs       TFR  \
# 0      -0.379248    0.187651 -0.084551           0.086093 -1.082080
# 1      -0.379248    0.187651 -0.084551           0.102675 -1.082080
# 2       0.326387   -0.066943  0.473789           0.080566 -0.507799
# 3      -0.391962   -0.800520 -0.078277           0.379030 -0.220659
# 4       1.241805   -1.037853 -0.918924           0.439828  1.215045
#
#    ANCCheckup  InstutitionalBirth  Breastfeeding       IMR
# 0    0.938069            1.381515       1.276926 -0.617242
# 1    0.932931            1.378003       1.276926 -0.617242
# 2   -0.464729            0.644028       0.879360  0.040990
# 3   -1.240636           -1.048681       0.855625  0.952387
# 4   -1.518113            0.405223       0.285979  0.040990

# %%
NFHS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 9 columns):
# DrinkingWater         111 non-null float64
# Sanitation            111 non-null float64
# Literate              111 non-null float64
# MarrageBelow18Yrs     111 non-null float64
# TFR                   111 non-null float64
# ANCCheckup            111 non-null float64
# InstutitionalBirth    111 non-null float64
# Breastfeeding         111 non-null float64
# IMR                   111 non-null float64
# dtypes: float64(9)
# memory usage: 7.9 KB

# %%
feature_cols = ['DrinkingWater','Sanitation','Literate','MarrageBelow18Yrs','TFR','ANCCheckup','InstutitionalBirth','Breastfeeding','IMR'] # create a Python list of feature names
X = NFHS[feature_cols]                                     # use the list to select a subset of the original DataFrame-+

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (111, 9)

# %%
y = NFHS.IMR
y.head()
# Out:
# 0   -0.617242
# 1   -0.617242
# 2    0.040990
# 3    0.952387
# 4    0.040990
# Name: IMR, dtype: float64

# %%
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (111,)

# %%
from sklearn.model_selection import train_test_split

def split(X,y):
    return train_test_split(X, y, test_size=0.20, random_state=1)

# %%
X_train, X_test, y_train, y_test=split(X,y)
print('Train cases as below')
print('X_train shape: ',X_train.shape)
print('y_train shape: ',y_train.shape)
print('\nTest cases as below')
print('X_test shape: ',X_test.shape)
print('y_test shape: ',y_test.shape)
# Out:
# Train cases as below
# X_train shape:  (88, 9)
# y_train shape:  (88,)
#
# Test cases as below
# X_test shape:  (23, 9)
# y_test shape:  (23,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

linreg = LinearRegression() #i will be doing a lin regression

linreg.fit(X_train,y_train) #this is my training data, calculate the the beta values

y_pred_test = linreg.predict(X_test) #not that you have beta values, calcutlate the prediction for test set

RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)) #calculate how much error we made on the test

# %%
def linear_reg( X, y, gridsearch = False):
    
    X_train, X_test, y_train, y_test = split(X,y)
    
    from sklearn.linear_model import LinearRegression
    linreg = LinearRegression()
    
    if not(gridsearch):
        linreg.fit(X_train, y_train) 

    else:
        from sklearn.model_selection import GridSearchCV
        parameters = {'normalize':[True,False], 'copy_X':[True, False]}
        linreg = GridSearchCV(linreg,parameters, cv = 10,refit = True)
        linreg.fit(X_train, y_train)                                                           # fit the model to the training data (learn the coefficients)
        print("Mean cross-validated score of the best_estimator : ", linreg.best_score_)  
        
        y_pred_test = linreg.predict(X_test)                                                   # make predictions on the testing set

        RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))                          # compute the RMSE of our predictions
        print('RMSE for the test set is {}'.format(RMSE_test))

    return linreg

# %%
X = NFHS[feature_cols]  
y = NFHS.IMR
linreg = linear_reg(X,y)

# %%
print('Intercept:',linreg.intercept_)          # print the intercept 
print('Coefficients:',linreg.coef_)
# Out:
# Intercept: 1.3877787807814457e-17
# Coefficients: [ 5.90368838e-16 -1.42688306e-16 -2.73363007e-16  2.06104435e-17
#  -1.16899385e-16  4.32262006e-17 -5.11311949e-16  1.59812284e-16
#   1.00000000e+00]

# %%
feature_cols.insert(0,'Intercept')
coef = linreg.coef_.tolist()            
coef.insert(0, linreg.intercept_)

# %%
eq1 = zip(feature_cols, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept 1.3877787807814457e-17
# DrinkingWater 5.903688375355658e-16
# Sanitation -1.4268830567963103e-16
# Literate -2.733630067025112e-16
# MarrageBelow18Yrs 2.0610443492986064e-17
# TFR -1.1689938529702782e-16
# ANCCheckup 4.322620062153288e-17
# InstutitionalBirth -5.113119486352111e-16
# Breastfeeding 1.5981228372582712e-16
# IMR 1.0000000000000004

# %% [markdown]
# __y = 1.3878 + 5.9036 `*` DrinkingWater + -1.4269 `*` Sanitation + -2.7336 `*` Literate + 2.0610 `*` Marrage Below 18 Yrs + -1.1690 `*` TFR + 4.4226 `*` ANC Checkup + -5.1131 `*` Institutional Birth + 1.5981 `*` Breastfeeding__

# %%
y_pred_train = linreg.predict(X_train)

# %%
y_pred_test = linreg.predict(X_test)

# %%
MAE_train = metrics.mean_absolute_error(y_train, y_pred_train)
MAE_test = metrics.mean_absolute_error(y_test, y_pred_test)

print('MAE for training set is {}'.format(MAE_train))
print('MAE for test set is {}'.format(MAE_test))
# Out:
# MAE for training set is 9.14396399507502e-16
# MAE for test set is 7.596580369581914e-16

# %%
MSE_train = metrics.mean_squared_error(y_train, y_pred_train)
MSE_test = metrics.mean_squared_error(y_test, y_pred_test)

print('MSE for training set is {}'.format(MSE_train))
print('MSE for test set is {}'.format(MSE_test))
# Out:
# MSE for training set is 1.1347055346556368e-30
# MSE for test set is 1.0922618603296324e-30

# %%
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 1.0652255792345755e-15
# RMSE for test set is 1.0451133241565875e-15

# %%
yhat = linreg.predict(X_train)
SS_Residual = sum((y_train-yhat)**2)
SS_Total = sum((y_train-np.mean(y_train))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 1.0 1.0

# %%
yhat = linreg.predict(X_test)
SS_Residual = sum((y_test-yhat)**2)
SS_Total = sum((y_test-np.mean(y_test))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 1.0 1.0

# %%
feature_cols = ['DrinkingWater','Sanitation','Literate','MarrageBelow18Yrs','TFR','ANCCheckup','InstutitionalBirth','Breastfeeding','IMR']  # create a Python list of feature names
X = NFHS[feature_cols]  
y = NFHS.IMR
linreg=linear_reg(X,y,gridsearch=True)
# Out:
# Mean cross-validated score of the best_estimator :  1.0
# RMSE for the test set is 2.368056811224089e-15
